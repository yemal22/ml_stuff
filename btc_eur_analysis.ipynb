# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pwd
# Out:
# /home/morel/Documents/ml_stuff

# %%
bitcoin = pd.read_csv('files/BTC-EUR.csv', index_col='Date', parse_dates=True)
# bitcoin = pd.read_csv('files/BTC-EUR.csv')
# bitcoin['Date'] = pd.to_datetime(bitcoin['Date'])
# bitcoin.set_index('Date', inplace=True)

# %%
bitcoin.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#               Volume
# Date
# 2014-09-17  16389166
# 2014-09-18  26691849
# 2014-09-19  29560103
# 2014-09-20  28736826
# 2014-09-21  20702625

# %%
bitcoin['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2024-08-06', '2024-08-07', '2024-08-08', '2024-08-09',
#                '2024-08-10', '2024-08-11', '2024-08-12', '2024-08-13',
#                '2024-08-14', '2024-08-15'],
#               dtype='datetime64[ns]', name='Date', length=3621, freq=None)

# %%
bitcoin.loc['2019', 'Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.loc['2017-09', 'Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.loc['2019', 'Close'].resample('M').sum().plot()
# Out:
# <Axes: xlabel='Date'>
