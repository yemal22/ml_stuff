# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bitcoin = pd.read_csv('files/BTC-EUR.csv')

# %%
bitcoin.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1  2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2  2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3  2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4  2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume
# 0  16389166
# 1  26691849
# 2  29560103
# 3  28736826
# 4  20702625

# %%
bitcoin.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1  2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2  2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3  2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4  2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume
# 0  16389166
# 1  26691849
# 2  29560103
# 3  28736826
# 4  20702625

# %%
bitcoin.index
# Out:
# RangeIndex(start=0, stop=3621, step=1)

# %%
bitcoin['Close'].plot(figsize=(9, 6))
# Out:
# <Axes: >

# %%
btc = pd.read_csv('files/BTC-EUR.csv', index_col='Date', parse_dates=True)

# %%
btc.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2024-08-06', '2024-08-07', '2024-08-08', '2024-08-09',
#                '2024-08-10', '2024-08-11', '2024-08-12', '2024-08-13',
#                '2024-08-14', '2024-08-15'],
#               dtype='datetime64[ns]', name='Date', length=3621, freq=None)

# %%
btc['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
btc.loc['2019', 'Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
btc.loc['2019-09':'2020', 'Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
btc.loc['2019', 'Close'].resample('M').plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 btc.loc['2019', 'Close'].resample('M').plot()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/resample.py:204, in Resampler.__getattr__(self, attr)
#     201 if attr in self.obj:
#     202     return self[attr]
# --> 204 return object.__getattribute__(self, attr)
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'plot'
