# %%
# %pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import missingno as mno

# %%
df = pd.read_csv('../../files/products.csv')
df
# Out:
#           ID               brand  \
# 0          1       Butter London
# 1          2       Butter London
# 2          3       Butter London
# 3          4       Butter London
# 4          5       Butter London
# ...      ...                 ...
# 10662  10891    Make Up For Ever
# 10663  10892  Marc Jacobs Beauty
# 10664  10893         Urban Decay
# 10665  10894     Tom Ford Beauty
# 10666  10895     Tom Ford Beauty
#
#                                                  name     product_type  \
# 0                          Handbag Holiday Cutile Oil    \nTreatment\n
# 1                                               LIPPY     \nLipgloss\n
# 2                        Hardwear P.D. Quick Top Coat     \nTop Coat\n
# 3                         Horse Power Nail Fertilizer    \nTreatment\n
# 4               Kitten Heels Powder Finish Foot Creme        \nCream\n
# ...                                               ...              ...
# ...

# %%
df.shape
# Out:
# (10667, 11)

# %%
df.isna().sum()
# Out:
# ID                  0
# brand               0
# name                0
# product_type       12
# img              9473
# rating          10667
# dupes           10667
# description         0
# shade_img        4120
# price_site      10666
# view_count          0
# dtype: int64

# %%
mno.bar(df)
# Out:
# <Axes: >

# %%
mno.dendrogram(df)
# Out:
# <Axes: >

# %%
mno.matrix(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10667 entries, 0 to 10666
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            10667 non-null  int64
#  1   brand         10667 non-null  object
#  2   name          10667 non-null  object
#  3   product_type  10655 non-null  object
#  4   img           1194 non-null   object
#  5   rating        0 non-null      float64
#  6   dupes         0 non-null      float64
#  7   description   10667 non-null  object
#  8   shade_img     6547 non-null   object
#  9   price_site    1 non-null      object
#  10  view_count    10667 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 916.8+ KB

# %%
df = df[['brand', 'name', 'product_type', 'img', 'description', 'shade_img']]
df
# Out:
#                     brand                                            name  \
# 0           Butter London                      Handbag Holiday Cutile Oil
# 1           Butter London                                           LIPPY
# 2           Butter London                    Hardwear P.D. Quick Top Coat
# 3           Butter London                     Horse Power Nail Fertilizer
# 4           Butter London           Kitten Heels Powder Finish Foot Creme
# ...                   ...                                             ...
# 10662    Make Up For Ever                             Artist Liquid Matte
# 10663  Marc Jacobs Beauty  Fineliner Ultra-Skinny Gel Eye Crayon Eyeliner
# 10664         Urban Decay                               Naked Flush Blush
# 10665     Tom Ford Beauty                         Shade & Illuminate Lips
# 10666     Tom Ford Beauty                    Shade & Illuminate Lip Color
#
#           product_type                                                img  \
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# e.l.f.                 526
# MAC                    522
# Sephora                513
# BH Cosmetics           391
# L'Oreal                322
#                       ...
# Rosebud Perfume Co.      1
# INM                      1
# Poshe                    1
# CND                      1
# J. Cat Beauty            1
# Name: count, Length: 423, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['brand'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x716c3d146350>,
# ...
#  [Text(1.0868271230721878, 0.16972567441206948, ''),
#   Text(0.9839096649771543, 0.4918554372623568, ''),
#   Text(0.7909336240846613, 0.7644762928255551, ''),
#   Text(0.5619269533384222, 0.9456416335545927, ''),
#   Text(0.35246474842023096, 1.0420022078292652, ''),
#   Text(0.1506553972209004, 1.0896343199845593, ''),
#   Text(-0.03125858139331301, 1.099555774433147, ''),
#   Text(-0.18555139234533097, 1.0842373729025896, ''),
#   Text(-0.33090941885135833, 1.0490466893877777, ''),
#   Text(-0.46516553536429844, 0.9968054096508735, ''),
#   Text(-0.587066159315176, 0.9302436909686238, ''),
#   Text(-0.6973551297293564, 0.8507031344953142, ''),
#   Text(-0.7925080063787564, 0.7628440599661043, ''),
#   Text(-0.8721542686896753, 0.6703334480737013, ''),
#   Text(-0.9393779873277007, 0.5723364368307843, ''),
#   Text(-0.994533186253747, 0.47000398023843365, ''),
#   Text(-1.0367532538385855, 0.3676175875214701, ''),
# ...

# %%
df['brand'].hist()
# Out:
# <Axes: >

# %%
df['brand'].value_counts()
# Out:
# brand
# e.l.f.                 526
# MAC                    522
# Sephora                513
# BH Cosmetics           391
# L'Oreal                322
#                       ...
# Rosebud Perfume Co.      1
# INM                      1
# Poshe                    1
# CND                      1
# J. Cat Beauty            1
# Name: count, Length: 423, dtype: int64

# %%
df['brand'].value_counts()[0]
# Out:
# /tmp/ipykernel_496652/3356541674.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['brand'].value_counts()[0]
# 526

# %%
df['brand'].value_counts().index[0]
# Out:
# 'e.l.f.'

# %%
def handle_categorical_features(feature, df):
    df[feature].fillna(df[feature].value_counts().index[0], inplace=True)

# %%
for feature in df.columns:
    handle_categorical_features(feature, df)
# Out:
# /tmp/ipykernel_496652/464162107.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[feature].fillna(df[feature].value_counts().index[0], inplace=True)
# /tmp/ipykernel_496652/464162107.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[feature].fillna(df[feature].value_counts().index[0], inplace=True)
# /tmp/ipykernel_496652/464162107.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
mno.bar(df)
# Out:
# <Axes: >
