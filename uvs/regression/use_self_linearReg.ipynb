# %%
from LinearRegression import LinearRegression
from sklearn.datasets import make_regression
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import axes3d
from sklearn.decomposition import PCA

# %%
X, y = make_regression(n_samples=1000, n_features=1)

# %%
X.shape
# Out:
# (1000, 1)

# %%
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
df = pd.DataFrame(X, columns = [f'feature_{i}' for i in range(X.shape[1])])
df['target'] = y
df
# Out:
#      feature_0      target
# 0     0.273534   23.425572
# 1     1.543269  132.166268
# 2    -0.747927  -64.052813
# 3    -1.231738 -105.486636
# 4     0.737868   63.191315
# ..         ...         ...
# 995   0.849415   72.744239
# 996  -1.365452 -116.937904
# 997  -0.093473   -8.005053
# 998   2.150640  184.181764
# 999  -0.640392  -54.843443
#
# [1000 rows x 2 columns]

# %%
sns.pairplot(df)
# Out:
# /home/morel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/morel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.corr()
# Out:
#            feature_0  target
# feature_0        1.0     1.0
# target           1.0     1.0

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.5)
# Out:
# <Axes: >

# %%
regression = LinearRegression(n_iterations=4000)

# %%
regression.fit(X, y)

# %%
plt.figure()
plt.scatter(X, y)
plt.plot(X, regression.predict(X), c='r')

# %%
X, y = make_regression(n_samples=1000, n_features=2)

# %%
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
df = pd.DataFrame(X, columns = [f'feature_{i}' for i in range(X.shape[1])])
df['target'] = y
df
# Out:
#      feature_0  feature_1      target
# 0    -1.275736  -0.294066  -80.876401
# 1     0.275453  -1.802437 -104.099770
# 2    -0.569446  -0.307310  -47.569840
# 3    -0.086443  -0.768273  -54.233764
# 4    -1.258955   0.303629  -41.125702
# ..         ...        ...         ...
# 995  -0.242020   0.758411   37.700621
# 996  -0.054507   0.973234   60.767644
# 997  -1.049454   0.593958  -12.075857
# 998   0.203727   0.597654   48.792285
# 999   2.462241  -0.912456   59.675024
#
# [1000 rows x 3 columns]

# %%
sns.pairplot(df)
# Out:
# /home/morel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/morel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/morel/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.5)
# Out:
# <Axes: >

# %%
regression = LinearRegression(n_iterations=4000)

# %%
regression.fit(X, y)
